# %%
import pandas as pd

dataset = pd.read_excel("../data/raw/Tierra_Del_Fuego_Delitos.xlsx") #importo el dataset

dataset.head()
# Out:
#   Delitos con intervención policial por mes, según tipo de delito. Provincia de Tierra del Fuego AeIAS. Años 2014-2023  \
# 0                                                NaN
# 1                                    Tipo de Delito
# 2                                                NaN
# 3                                                NaN
# 4                           Total Hechos delictuosos
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN       2014        NaN        NaN        NaN
# 2        ene        feb        mar        abr        may        jun
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        453        524        606        579        558        664
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 116 Unnamed: 117  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# ...
